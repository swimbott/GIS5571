# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# /opt/conda/lib/python3.9/site-packages/arcgis/gis/__init__.py:597: UserWarning: You are logged on as bott0137_UMN with an administrator role, proceed with caution.
#   warnings.warn(

# %% [markdown]
# #### Now you are ready to start!

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.991192%2C-93.260567&radius=2500&type=restaurant&keyword=subs&key=AIzaSyAOnstvDO861Lpg-4Jw8LlWWEaXEflkQ-4"

# restaurant/sub stations in mlps

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "AcYSjRhM_FCF5279QK8oU36UBUdDzPfKvRHKUaRmglGrJNzmmkAHAcdikcEYlZ7AalHe0VLB06ucaqi3kbflZM0Ro8CTNvRmrLDCiek8jaCONCs_tFTN4IcMoYTb1uXO4lMK8S9UA7b6CIhwJq_gGzxstNdK0x8pXVuzbwOmrhF2mILrAY-uqd3kXGBQWsA664ymf8b-25_n_MPBgqcz-Zcgd_QJBhGSZmixVu337BZe9wc48EBuOmZ0JFmAdd2uKx2gMQonUYW-r7CY0IjteljvT4N8sW8XlXP3bALhuUrogKGeO-i44xV02pVO0kihobEk7cBLhntDCqek9f0gFs_h0Qq8tSLquV33fZZjJ9uc7XB-J3LJSHdNxWANsdzp0CulmCcH-UQZZlox492OXWyuP9waFoTWailSGNXdgbj30Fh3SPrKeG8e5uwSbIZCX3PPHeeh",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.97710559999999,
#                "lng" : -93.26770169999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97815252989272,
#                   "lng" : -93.26661072010728
#                },
#                "southwest" : {
#                   "lat" : 44.97545287010728,
#                   "lng" : -93.26931037989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2988,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/116320941429019902284\"\u003eJon Goetz\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgot8BxyWtWbo5KXTlY7i64IoJRUecnNUfcxxUYpENbLBgTp-yRyKcolm70NrGkLauFrs-9Gp_PQGzMJkzHWHDysX7z6MRmH-B6OHZdt0Xc-C9YAZ_q4erL1QLi3LD42-UIg5RrdpYPxrHo6VidL9uUh_c-dsmVQqeMlW9zAtl2x6h3",
#                "width" : 5312
#             }
#          ],
#          "place_id" : "ChIJc5_y9Jkys1IRPQNfVsXksFI",
#          "plus_code" : {
#             "compound_code" : "XPGJ+RW Minneapolis, Minnesota",
#             "global_code" : "86P8XPGJ+RW"
#          },
#          "price_level" : 1,
#          "rating" : 3.9,
#          "reference" : "ChIJc5_y9Jkys1IRPQNfVsXksFI",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 79,
#          "vicinity" : "Pillsbury Center, 200 South 6th St, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.98064979999999,
#                "lng" : -93.23546639999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98199412989273,
#                   "lng" : -93.23417847010728
#                },
#                "southwest" : {
#                   "lat" : 44.97929447010728,
#                   "lng" : -93.23687812989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 1920,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109747601842520657395\"\u003eRebekkah Gross\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRjoR4dJF85sKgaEhlNZBX63DLdfULQ8rv217NxVaPC7Kdr70WKRtrL8TkbpsmNw-M7iqJSFqi4g1cMYM6tvdOtbP6dW1_nJDf3OtsUk7LpOafL_zPT9zAwInchdun28LobxBWuFDaaRgO0WrB6fWa6EOEaGRvdLqVtfsJzYyqJZ8UX-",
#                "width" : 1080
#             }
#          ],
#          "place_id" : "ChIJbxmmkREts1IRl8sU3re1Flw",
#          "plus_code" : {
#             "compound_code" : "XQJ7+7R Minneapolis, Minnesota",
#             "global_code" : "86P8XQJ7+7R"
#          },
#          "price_level" : 1,
#          "rating" : 3.1,
#          "reference" : "ChIJbxmmkREts1IRl8sU3re1Flw",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 81,
#          "vicinity" : "404 14th Ave SE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9790105,
#                "lng" : -93.2745498
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98042597989272,
#                   "lng" : -93.27303102010728
#                },
#                "southwest" : {
#                   "lat" : 44.97772632010728,
#                   "lng" : -93.27573067989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2576,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/104315725450080544213\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgrEBFwY3trvUYr8WHr-KKiTaW3PbBEAV1kyF2CTeAypxcWsd7zvzCF5o46NdPC0yJ7vApPgC7_Iolv10MP4aYFO4JnGoy4iPYdXWRIF8o1KWYELYZcBzhl0HaDZI675Fia8iLMV0Cu2VwM5VESKXV47BnxKVvhd1ENqAQkZ3KBSwI9",
#                "width" : 1932
#             }
#          ],
#          "place_id" : "ChIJVecVpZEys1IRUTDqtui07Wg",
#          "plus_code" : {
#             "compound_code" : "XPHG+J5 Minneapolis, Minnesota",
#             "global_code" : "86P8XPHG+J5"
#          },
#          "price_level" : 1,
#          "rating" : 3.5,
#          "reference" : "ChIJVecVpZEys1IRUTDqtui07Wg",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 254,
#          "vicinity" : "600 Hennepin Ave Ste. 140, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 45.0055929,
#                "lng" : -93.22821689999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.00692017989272,
#                   "lng" : -93.22686652010728
#                },
#                "southwest" : {
#                   "lat" : 45.00422052010728,
#                   "lng" : -93.22956617989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Erbert and Gerberts",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 657,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/116180860881859690702\"\u003eErbert and Gerberts\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRg8wk4aavGs9ZyYNlPOB2UqQizlnzrBZneNpZslSNENv-LM44abGnrCrsb50PsI9hbsz6BPS-5McpczMOJ34MH4yZAhH1MtjjU92BDoUy7HLLNrnJHwU83t137JHVmPTfriC7qg0-XT8E_fRtuGWqv18b3pGZgsOYlUQPgP_RCTJl0C",
#                "width" : 1773
#             }
#          ],
#          "place_id" : "ChIJM10G97Mts1IRKkbmKU3WdoQ",
#          "plus_code" : {
#             "compound_code" : "2Q4C+7P Minneapolis, Minnesota",
#             "global_code" : "86Q82Q4C+7P"
#          },
#          "price_level" : 1,
#          "rating" : 3.5,
#          "reference" : "ChIJM10G97Mts1IRKkbmKU3WdoQ",
#          "scope" : "GOOGLE",
#          "types" : [
#             "restaurant",
#             "meal_delivery",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 122,
#          "vicinity" : "1730 New Brighton Blvd, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.97618629999999,
#                "lng" : -93.27190450000001
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97774397989272,
#                   "lng" : -93.27036847010729
#                },
#                "southwest" : {
#                   "lat" : 44.97504432010728,
#                   "lng" : -93.27306812989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Potbelly",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 900,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117071218813406850574\"\u003ePotbelly Sandwich Shop\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgjB7i6RIHjFe2WS6LeDaLIfXtbZdJzmXngTv91cEHw5AdgVgqq27pi8fBrcLTMJVJaEEawGWR8wh7p1PtfTVgQWtuaaWSUboNztr3BcraK3unteVasst7Y6g6KmV9apJfjZvhzcAqII3kJH6VZE4bQuVBfPYrNb6v0nPPHK6VUe7Sj",
#                "width" : 1600
#             }
#          ],
#          "place_id" : "ChIJ5RvcOJcys1IRj6Od8qMxN08",
#          "plus_code" : {
#             "compound_code" : "XPGH+F6 Minneapolis, Minnesota",
#             "global_code" : "86P8XPGH+F6"
#          },
#          "price_level" : 1,
#          "rating" : 4.2,
#          "reference" : "ChIJ5RvcOJcys1IRj6Od8qMxN08",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 250,
#          "vicinity" : "IDS Center, 80 S 8th St #210, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 45.0094855,
#                "lng" : -93.2372893
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.01087757989272,
#                   "lng" : -93.23594422010729
#                },
#                "southwest" : {
#                   "lat" : 45.00817792010728,
#                   "lng" : -93.23864387989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Marino's Deli",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107929106225739135555\"\u003eBen Ernst\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRg7x9gCPKxyyJow0OMQbm4yIz-o480MHePf0ZjiPDus5_YNJyJTBV-nHytO78yXxOsVrrwk3aIzbESprsEoYvWAkffFi-Xpvhat505DBj4abCXyYUf_4pVZGnkEwuembxe_wg-wqFcEfa9cvPc1fH80F9kBDmzuz64mmITS9hP6DM-l",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJ1S3ajrgts1IR1G42KRLPIuM",
#          "plus_code" : {
#             "compound_code" : "2Q57+Q3 Minneapolis, Minnesota",
#             "global_code" : "86Q82Q57+Q3"
#          },
#          "price_level" : 1,
#          "rating" : 4.7,
#          "reference" : "ChIJ1S3ajrgts1IR1G42KRLPIuM",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "store", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 295,
#          "vicinity" : "1946 Johnson St NE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9813069,
#                "lng" : -93.23726789999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98254467989272,
#                   "lng" : -93.23589187010727
#                },
#                "southwest" : {
#                   "lat" : 44.97984502010728,
#                   "lng" : -93.23859152989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Frank From Philly & Andrea Pizza",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 2517,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/114113171544185055298\"\u003eRuss Freer\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRimsjiMdQoeTh2wic3DStiRbSQu0swNwadAI_pghEtAAuxJhy7bc4DWgRbgdZ78FXAcImKrsR790MNRHCzlnNOCLlu0EnMdIVy1fck_x32HxDNxtJQNZdpRAZJK6Nq2dJivPpj2pJGbSdhTtoilaIBFy9LPTCYGz_e4-IlgZUMXia_J",
#                "width" : 2517
#             }
#          ],
#          "place_id" : "ChIJlV0jFRIts1IR4c_yL0heZxc",
#          "plus_code" : {
#             "compound_code" : "XQJ7+G3 Minneapolis, Minnesota",
#             "global_code" : "86P8XQJ7+G3"
#          },
#          "price_level" : 1,
#          "rating" : 4.4,
#          "reference" : "ChIJlV0jFRIts1IR4c_yL0heZxc",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 1058,
#          "vicinity" : "1235 4th St SE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9803281,
#                "lng" : -93.23570269999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98170692989272,
#                   "lng" : -93.23435777010729
#                },
#                "southwest" : {
#                   "lat" : 44.97900727010727,
#                   "lng" : -93.23705742989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Potbelly",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 900,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103819317967180149776\"\u003ePotbelly Sandwich Shop\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRh4UzD7wCnYq-pPU60HaWAdY9YGeAaZRSNeasclJeV2QxX0MVindpOWoM79C0Kbbh4IBYHCNcwTxkma44_nMngdSJjZPTKbLdUyIKUN24mdbRuzE03WN3SvfU9Q7oK2nnF6s0TL-HP1UrFJtEX2n76I4w5lYn3DFgwYdWqOyIYn6qFa",
#                "width" : 1600
#             }
#          ],
#          "place_id" : "ChIJIXeR1BMts1IRhW-Qf5QY77Q",
#          "plus_code" : {
#             "compound_code" : "XQJ7+3P Minneapolis, Minnesota",
#             "global_code" : "86P8XQJ7+3P"
#          },
#          "price_level" : 1,
#          "rating" : 4.2,
#          "reference" : "ChIJIXeR1BMts1IRhW-Qf5QY77Q",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 238,
#          "vicinity" : "326 14th Ave SE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9746617,
#                "lng" : -93.2728771
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97599772989272,
#                   "lng" : -93.27156962010727
#                },
#                "southwest" : {
#                   "lat" : 44.97329807010728,
#                   "lng" : -93.27426927989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/100000868373124470553\"\u003eThomas Miranda\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRin60jtP9UBvjfKeV4TmgFmnr8XzMlZUqUU-bov9ghqxMXqIkQdiOtuWogCXck-wMi4_d2y9pJNLauKUP-yoYkBvmwJbe8G8z4f6fUhhcqxF8O_nhrI-pU-0NQC4gWzcZnD1N9c4OZiuy5pBZvEuB58IhJvUYZbRY0J06aCt37cUi2a",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJN0sMBZcys1IRge7yBlQeGSQ",
#          "plus_code" : {
#             "compound_code" : "XPFG+VV Minneapolis, Minnesota",
#             "global_code" : "86P8XPFG+VV"
#          },
#          "price_level" : 1,
#          "rating" : 3.7,
#          "reference" : "ChIJN0sMBZcys1IRge7yBlQeGSQ",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 108,
#          "vicinity" : "88 S 9th St, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9763375,
#                "lng" : -93.2582262
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97764467989272,
#                   "lng" : -93.25692482010727
#                },
#                "southwest" : {
#                   "lat" : 44.97494502010728,
#                   "lng" : -93.25962447989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101571478110257612431\"\u003eNic A\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhAP_lYin8_4VLFHOSN9aAn3hG1_39CM3nCdv7dxLCc_VhXYt_wRH7YAVRMoTX3se4vsEtV3e_D1qX7Ieu6Ls2P9hDqm24APgMgJH2Q18ig40OxLC8ctia78X9Bet_ck4yoeumeTF0qWHpsZMpPIi2Cyq5bzJZvLnSQgHvAqcYEJBnw",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJ_2UPHpwts1IReSJVr59OmKU",
#          "plus_code" : {
#             "compound_code" : "XPGR+GP Minneapolis, Minnesota",
#             "global_code" : "86P8XPGR+GP"
#          },
#          "price_level" : 1,
#          "rating" : 4.2,
#          "reference" : "ChIJ_2UPHpwts1IReSJVr59OmKU",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 45,
#          "vicinity" : "720 S 3rd St, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.999456,
#                "lng" : -93.28158499999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.00072627989272,
#                   "lng" : -93.28031987010728
#                },
#                "southwest" : {
#                   "lat" : 44.99802662010728,
#                   "lng" : -93.28301952989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pappy's Minneapolis",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 1960,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117745224361265727010\"\u003eStefan Georgiev\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRg07dzjAuoJ32uZhC5gJfPLk_bMfPHtWoQuQPoEizsfRwFySOL5tkSaxttnZd1otwYAZNbP3xVagFRtk_v3hxYUpLDRE5MW8Zxr14WvrLV1zB_82XB6-BNB1G3DYof_YPDAZJlXPKh4xuksvPM0Fv9aGFJfgE2ALAXjP2ddgaDqwGo",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJB2xDII0ts1IRZzkbLi7w9cg",
#          "plus_code" : {
#             "compound_code" : "XPX9+Q9 Minneapolis, Minnesota",
#             "global_code" : "86P8XPX9+Q9"
#          },
#          "price_level" : 1,
#          "rating" : 4.1,
#          "reference" : "ChIJB2xDII0ts1IRZzkbLi7w9cg",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 817,
#          "vicinity" : "2006 N Washington Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9745107,
#                "lng" : -93.2817637
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97575587989272,
#                   "lng" : -93.28030397010728
#                },
#                "southwest" : {
#                   "lat" : 44.97305622010727,
#                   "lng" : -93.28300362989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Subway",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111049603451013690605\"\u003eTakeysha Robinson\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRjX-K82tD6BVDmH21C2hoXu04fHEdE5-dHRMMACCrJqGzGSbyyIT6F12o_haUHouPJDVDwMn2l5PoxsWRC_vqeGL8Kgg27AuRGnxcAB-GuAPlvjq503i8ML0yPgcJ4H690ycEWeVZ9IAvQiySbdFnR7234fat9xgCm1wjOXtEQADY5F",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJ1QjwLusys1IRcF4RK45IFp8",
#          "plus_code" : {
#             "compound_code" : "XPF9+R7 Minneapolis, Minnesota",
#             "global_code" : "86P8XPF9+R7"
#          },
#          "price_level" : 1,
#          "rating" : 3.7,
#          "reference" : "ChIJ1QjwLusys1IRcF4RK45IFp8",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 188,
#          "vicinity" : "1260 Hennepin Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9783179,
#                "lng" : -93.26135669999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97974952989272,
#                   "lng" : -93.26002122010726
#                },
#                "southwest" : {
#                   "lat" : 44.97704987010727,
#                   "lng" : -93.26272087989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Subway",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/100392103522171333895\"\u003e100392103522171333895\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhby6XOmmKgoKgNKVDC_P9o1TTfBXVenOyYuSgrAbxaTw7f85zixg_v815XexY-XQal2kzCWY679NEOD4e-FQ8EYeF3Sp7S3ySSvSz1uLLdr33IX3JS-vtWE0blJizwB9GgDIkAWC_QEURL7p3RYJ3ktzJ7Co5oHBws4en854JRMFBH",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJk4z6iZ0ys1IR-QAZvyby1GQ",
#          "plus_code" : {
#             "compound_code" : "XPHQ+8F Minneapolis, Minnesota",
#             "global_code" : "86P8XPHQ+8F"
#          },
#          "price_level" : 1,
#          "rating" : 3.3,
#          "reference" : "ChIJk4z6iZ0ys1IR-QAZvyby1GQ",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 144,
#          "vicinity" : "501 S Washington Ave Suite 170, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9777262,
#                "lng" : -93.26728849999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97898842989272,
#                   "lng" : -93.26615777010727
#                },
#                "southwest" : {
#                   "lat" : 44.97628877010727,
#                   "lng" : -93.26885742989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Subway",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 1945,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105058398746970423397\"\u003ePaul Jahn\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRj6lRAlEwZxSo6_hW9Wue3cCThuXQWmgLQ66gWjUBxyhZ2vaFbP1-ofLXanXKbqabsE8S1oebcq4uxa9OtOIeLGJgFoKGBY35kxaC9dzELW9viTTwbQliAa7Vuk1uNkyQIyqaFAMp_lzy6CPb5OlKzjvyYcWGXvMRPl41WhM5o9t1A-",
#                "width" : 3902
#             }
#          ],
#          "place_id" : "ChIJAQjuxpsys1IRfyBWJfQyKIg",
#          "plus_code" : {
#             "compound_code" : "XPHM+33 Minneapolis, Minnesota",
#             "global_code" : "86P8XPHM+33"
#          },
#          "price_level" : 1,
#          "rating" : 3.9,
#          "reference" : "ChIJAQjuxpsys1IRfyBWJfQyKIg",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 58,
#          "vicinity" : "200 S 5th St, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.99003250000001,
#                "lng" : -93.2526707
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.99132642989272,
#                   "lng" : -93.2512786701073
#                },
#                "southwest" : {
#                   "lat" : 44.98862677010728,
#                   "lng" : -93.25397832989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Lu's Sandwiches",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/100987005086264349112\"\u003eAdam Hanson\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRht9zxH5yWb_VLqepZV0-C5KV42TECGeKMz1_ODK8nblVXYEQGDSH0jD-CgUz7HuXemKa_PSpjNBA4_rNJswGM0YSJbLzliksGHDjO4nhwIOXRU4Emh_jZ2LcqJHBqZlqEOQiAjWg1HPGx_686h6BPJs9SGRs8a73chN7DvrdDXHEfN",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJL4_lH3gts1IRrMqE72fIH40",
#          "plus_code" : {
#             "compound_code" : "XPQW+XV Minneapolis, Minnesota",
#             "global_code" : "86P8XPQW+XV"
#          },
#          "price_level" : 1,
#          "rating" : 4.5,
#          "reference" : "ChIJL4_lH3gts1IRrMqE72fIH40",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 575,
#          "vicinity" : "10 6th St NE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9983051,
#                "lng" : -93.28678699999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.99978597989272,
#                   "lng" : -93.28533497010727
#                },
#                "southwest" : {
#                   "lat" : 44.99708632010727,
#                   "lng" : -93.28803462989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Subway",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 918,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101676512339357740495\"\u003eSUBWAY® Restaurants\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgdJtgJF2n2Hwl8xtM7j8v9jOgBt7gq09tgdGqV2xjiIFjWxQmVqMxbrprttDrXmie1MDBm7nP5wiuQA2zH4IxXvRx-STIHFQGscVbpWqhzT9lDcwYVE0keBqCsSRe8cVjKgxeSiTeq8kkg1Dem2vdJzR9s0F6cCABhVVvDY4UR1CQ",
#                "width" : 918
#             }
#          ],
#          "place_id" : "ChIJ9UbZ0Fwys1IRExHgRUkajKE",
#          "plus_code" : {
#             "compound_code" : "XPX7+87 Minneapolis, Minnesota",
#             "global_code" : "86P8XPX7+87"
#          },
#          "price_level" : 1,
#          "rating" : 3,
#          "reference" : "ChIJ9UbZ0Fwys1IRExHgRUkajKE",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 86,
#          "vicinity" : "521 W Broadway Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9881935,
#                "lng" : -93.25673239999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98957187989272,
#                   "lng" : -93.25529562010728
#                },
#                "southwest" : {
#                   "lat" : 44.98687222010727,
#                   "lng" : -93.25799527989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/112572636738003768702\"\u003eDanae Bye\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgHuT-IDvuOr0vZ_zFGhYByl1MTPIidt8sxs_2jXlptMPmAbGeHc3fx-m1gFzudRF6ryWqr4MNxoK5UeoO3qug6-F528gUSW7YXZRoy7A3CmNb-wm4lz6drWcJYc7kD7tx6FWg2nzxkM9sJwUGuaB8O4YP9je2-8xXPb8FgFoQJJh0",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJ38qxKHkts1IRdGAz9ohlimc",
#          "plus_code" : {
#             "compound_code" : "XPQV+78 Minneapolis, Minnesota",
#             "global_code" : "86P8XPQV+78"
#          },
#          "price_level" : 1,
#          "rating" : 3,
#          "reference" : "ChIJ38qxKHkts1IRdGAz9ohlimc",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 111,
#          "vicinity" : "14 University Ave NE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 45.006346,
#                "lng" : -93.22712679999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.00758697989271,
#                   "lng" : -93.22586737010728
#                },
#                "southwest" : {
#                   "lat" : 45.00488732010727,
#                   "lng" : -93.22856702989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jimmy John's",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 1055,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107238778930402193732\"\u003ejoanne murphy\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhEBRN_X9Y4ba9754KNdi3WvcDZLBsG3170xtVQJS_4rPVXViFJDtaWJdw8-W7A9BUsE4buXdovM80M1odc1VZ0Mv8fbXlMUeKVHzZAKeMB85Dxtd4E69SNTSvvrrYaD_Kx_3yUX4-Kq0ODuwujbA4mzKXbo2IsC2sv301yyxKeEad-",
#                "width" : 1600
#             }
#          ],
#          "place_id" : "ChIJE-BGCrQts1IRQyDMaDlIfiQ",
#          "plus_code" : {
#             "compound_code" : "2Q4F+G4 Minneapolis, Minnesota",
#             "global_code" : "86Q82Q4F+G4"
#          },
#          "price_level" : 1,
#          "rating" : 3.4,
#          "reference" : "ChIJE-BGCrQts1IRQyDMaDlIfiQ",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 143,
#          "vicinity" : "2317 NE 18th Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9801963,
#                "lng" : -93.2661298
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98154057989272,
#                   "lng" : -93.26464967010729
#                },
#                "southwest" : {
#                   "lat" : 44.97884092010727,
#                   "lng" : -93.26734932989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Dagwoods",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3456,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/116087072167377940525\"\u003eRaja Mahesh Aravapalli\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgWFtLI5J2HiuGv7mfd1udkoAynHrohXqdciTPJ9VRmmUl2pfekRm9QdnSk1g3h8s5Sr0UAUVS0lTqfG1fyHj0BszCz_ixEAoL8lt9NdM6u2uOqS4XvbFeHdjuiMdf848iKY73M4rjYNaYHaw_1i8L8AqWH6nR7-_KtkmVjVN_GJo5n",
#                "width" : 4608
#             }
#          ],
#          "place_id" : "ChIJmaXYl5wys1IRfcAk7EEfC40",
#          "plus_code" : {
#             "compound_code" : "XPJM+3G Minneapolis, Minnesota",
#             "global_code" : "86P8XPJM+3G"
#          },
#          "price_level" : 1,
#          "rating" : 4.5,
#          "reference" : "ChIJmaXYl5wys1IRfcAk7EEfC40",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 79,
#          "vicinity" : "250 2nd Ave S #210, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9721039,
#                "lng" : -93.2434241
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97345372989273,
#                   "lng" : -93.24207427010728
#                },
#                "southwest" : {
#                   "lat" : 44.97075407010728,
#                   "lng" : -93.24477392989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Subway",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "place_id" : "ChIJATel2kEts1IRCNYKGBbVm8k",
#          "plus_code" : {
#             "compound_code" : "XQC4+RJ Minneapolis, Minnesota",
#             "global_code" : "86P8XQC4+RJ"
#          },
#          "price_level" : 1,
#          "rating" : 2.3,
#          "reference" : "ChIJATel2kEts1IRCNYKGBbVm8k",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 32,
#          "vicinity" : "269 19th Ave. South Blegan Hall, Minneapolis"
#       }
#    ],
#    "status" : "OK"
# }

# %%
import pandas
import json
r_json_restaurants=response.json()["results"]

# %%
df_restaurants=pandas.DataFrame(columns=("Name", "Latitude","Longitude"))

for feature in range(len(r_json_restaurants)):
    name=[r_json_restaurants[feature]["name"]]
    Latitude=[r_json_restaurants[feature]["geometry"]["location"]["lat"]]
    Longitude=[r_json_restaurants[feature]["geometry"]["location"]["lng"]]
    
    df_restaurants.loc[feature]=name+Latitude+Longitude
    
df_restaurants.head()
# Out:
#                   Name   Latitude  Longitude
# 0         Jimmy John's  44.977106 -93.267702
# 1         Jimmy John's  44.980650 -93.235466
# 2         Jimmy John's  44.979011 -93.274550
# 3  Erbert and Gerberts  45.005593 -93.228217
# 4             Potbelly  44.976186 -93.271905

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.991192%2C-93.260567&radius=25000&type=restaurant&keyword=pizza&key=AIzaSyBMKRI1bK3qW5KWmb1ZD1erCZ0f9yUEAEk"

# pizza places in mlps

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "AcYSjRi2xO0U5CQptiou8tA1K1reUxHrAOeKVCCMESWyemhm60cptNHlqKO-uzn0FwI_FnCVNb1OzxC3QjX--OqDKxp-oPVFsNoKU5ZsbIujf-ZRQN4A2sGzC8JwfGKd7CdCrnGxELg9bcg9Ze7b-m9y2F47VKzwJR24oA2l8tWETwUHJ1r5ulQbuGaIJwcCYaamy59b4AV6pVuVG9bJtxpBulHMtYARJ8gDzoytb019qOoCqKgrcAtXlnQwlqBDLufod9vM9L4KJEMBxQAhvmS71kqzjDsRnHsj08wR535W6QpxCrsblrHtHe5KSf4wdRmOw7qA_l0yMUi8XNY_Kp6AlSDDuIWQzw0FjEPd2v8U_oMfqFfPSGq56rRCf-DIymspdPV4Qd-xQwmAs3WkKYNWMV6wx6I2rE14egvc_jW3As24m8T_iCi1hj5PjTsZHUJM9Yvm_Q",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.901815,
#                "lng" : -93.3185998
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.90316827989272,
#                   "lng" : -93.31736697010729
#                },
#                "southwest" : {
#                   "lat" : 44.90046862010728,
#                   "lng" : -93.32006662989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizzeria Lola",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 6013,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105312468847967159153\"\u003eMarina Duchesneau\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhLzKWnrxulpDgbyOc0girB3YYWBIYF6D7KRAoyQGyVk-pB_BUFuSQLQCkxH0eGNysHvHpXWd5WCCaqdFIp7IiZtmdf1lp_glyrry4n9EEfuzi4bNIhG4E0c0QypMNGuDA5etlEp_Bt-KIjcH0rATLw-d7_SLujVpEYj6MXhaNNpRKG",
#                "width" : 4535
#             }
#          ],
#          "place_id" : "ChIJEWROdcIm9ocRbZQ9Buq-07w",
#          "plus_code" : {
#             "compound_code" : "WM2J+PH Minneapolis, Minnesota",
#             "global_code" : "86P8WM2J+PH"
#          },
#          "price_level" : 2,
#          "rating" : 4.7,
#          "reference" : "ChIJEWROdcIm9ocRbZQ9Buq-07w",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 2587,
#          "vicinity" : "5557 Xerxes Ave S, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9416096,
#                "lng" : -93.44443659999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.94290257989272,
#                   "lng" : -93.44306307010727
#                },
#                "southwest" : {
#                   "lat" : 44.94020292010728,
#                   "lng" : -93.44576272989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Station Pizzeria",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/102044729121681086000\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgDnlXjGkrAVc-OCWGx8yfMTCTXivZs0AGnAeOUruQOsJxc6iUp3K7iHpGvAoHHI6fUCZ4CTYjPSLH2kJidHnDfR8TdTO9Wt8w0tJzuHXkIZcaUbh6SxJOKYAhqHiNJ7ioMLHpWuV7Yy3owQiwE3VHFMyZ5UmDgNTOZ4gLWfXO-coXm",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJzXwpetwf9ocRL-0iKtaOym4",
#          "plus_code" : {
#             "compound_code" : "WHR4+M6 Minnetonka, Minnesota",
#             "global_code" : "86P8WHR4+M6"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJzXwpetwf9ocRL-0iKtaOym4",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 699,
#          "vicinity" : "13008 Minnetonka Blvd, Minnetonka"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 45.1585024,
#                "lng" : -93.3187562
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.16004587989272,
#                   "lng" : -93.31748452010727
#                },
#                "southwest" : {
#                   "lat" : 45.15734622010728,
#                   "lng" : -93.32018417989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizza Flame",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 400,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105711989136290507350\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgGfc4PbCsQhpPo-ZOF1GJaUezVSCYjnq0UEJBlMX-PVW_jbkAlTyks88KAYXgMuveMTZ_N84hnXWeowq7gbOV-riqvso1y_gCo9OJuvIT9UmMStZHxupK3WLbnlBOccROuBQ8oy6ubLHj5KJhN1YDipGYRSG6aBy_yXjwW1Wk5ekbE",
#                "width" : 1000
#             }
#          ],
#          "place_id" : "ChIJS05awHQ7s1IRoBrGWNUq9iA",
#          "plus_code" : {
#             "compound_code" : "5M5J+CF Coon Rapids, Minnesota",
#             "global_code" : "86Q85M5J+CF"
#          },
#          "price_level" : 2,
#          "rating" : 4.5,
#          "reference" : "ChIJS05awHQ7s1IRoBrGWNUq9iA",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "store",
#             "restaurant",
#             "point_of_interest",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 580,
#          "vicinity" : "2016 105th Ave NW, Coon Rapids"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8504082,
#                "lng" : -93.43152809999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.85174177989273,
#                   "lng" : -93.43018302010728
#                },
#                "southwest" : {
#                   "lat" : 44.84904212010728,
#                   "lng" : -93.43288267989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizza Karma - Eden Prairie",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 1960,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/115640749244801394506\"\u003eChase Nelson\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhLys5cCWoREn4VxRRisyLcCVelQxSPEVvI0pSixdXOm-bfpCWhJ9MSG5fazym2_xHL6B7L2asW1urAATaDp1-XCEljNwMqNGjUEvqsOe-TD7aWw76SE-QHKFHaQTiHrgvM5KwrmrJu4kI4M_tUHWgSavZKKrxgg0do4pVKXZyKl_wc",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJwRNHPooZ9ocRMGJd1ftvzrE",
#          "plus_code" : {
#             "compound_code" : "VH29+49 Eden Prairie, Minnesota",
#             "global_code" : "86P8VH29+49"
#          },
#          "price_level" : 2,
#          "rating" : 4.5,
#          "reference" : "ChIJwRNHPooZ9ocRMGJd1ftvzrE",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 516,
#          "vicinity" : "8451 Joiner Way, Eden Prairie"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9735252,
#                "lng" : -93.22352800000002
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97467902989272,
#                   "lng" : -93.22211427010728
#                },
#                "southwest" : {
#                   "lat" : 44.97197937010728,
#                   "lng" : -93.22481392989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Blaze Pizza",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 600,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110438771324882710440\"\u003eBlaze Pizza\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRguUCzLNoxEMoS4puSd9t8BLhp219Qh94nTMBgyxErQgl0c4M-hKliXTZ8cAolfRMH9J6awT2ZH04GEZti7P7BXXb7cGhePWiCp4JYmTHSONelKlhmlPzLwTmTBZlZYTCVmwd8zcVv1R2uPPlxubwdnYXegmINtMTxvHX2uDz69dntE",
#                "width" : 1080
#             }
#          ],
#          "place_id" : "ChIJdXBVYR8ts1IRQXsnCR0C8MQ",
#          "plus_code" : {
#             "compound_code" : "XQFG+CH Minneapolis, Minnesota",
#             "global_code" : "86P8XQFG+CH"
#          },
#          "price_level" : 1,
#          "rating" : 4.4,
#          "reference" : "ChIJdXBVYR8ts1IRQXsnCR0C8MQ",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "point_of_interest",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 1068,
#          "vicinity" : "1000 Washington Ave SE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.98175639999999,
#                "lng" : -93.2735524
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98316757989272,
#                   "lng" : -93.27214977010729
#                },
#                "southwest" : {
#                   "lat" : 44.98046792010728,
#                   "lng" : -93.27484942989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizza Lucé Downtown",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 1438,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109973266722858461708\"\u003eRonda Kisner\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgV-a8hWYo_QB3k9J_7stm6Y6NjkOmT6PcxZS3f0MriIv9V_Xw9FUJmZRwu8myaFWslsF86e3TfHQ1HZUD63puhj7q2XBySeAEGsA-RnOLj4iNQFYgcRo-n4WsKgRE2gYFbqsjeAjjx9eFdQ1G47siu_u9OqqLVQTv1NEZFdZ8Mbv8I",
#                "width" : 1438
#             }
#          ],
#          "place_id" : "ChIJ4S8J0Y8ys1IRmWaq0xTwphg",
#          "plus_code" : {
#             "compound_code" : "XPJG+PH Minneapolis, Minnesota",
#             "global_code" : "86P8XPJG+PH"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJ4S8J0Y8ys1IRmWaq0xTwphg",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 2805,
#          "vicinity" : "119 N 4th St, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8911825,
#                "lng" : -93.51493099999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.89253232989272,
#                   "lng" : -93.51361147010726
#                },
#                "southwest" : {
#                   "lat" : 44.88983267010727,
#                   "lng" : -93.51631112989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Detello's Pizza & Pasta",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/115306351358816418662\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRh1QlIoYKHI00-APHSxbysS041SJOimX3Wyugg0Jt_ZSJFz0PIlevjbAH1gBCjx2xEk9S7nbRKW1hpFfkthfQ6qiQIC8pQXKSOdSqarEHpt37VX9CmHQ2iJ8v4LqI2EMWUyb2w1cw3FIWKqMliEWUhXVyCR-tM2FZ349wFcPFQCmIl8",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJEzS3cz4c9ocRjQCr5VIjFwA",
#          "plus_code" : {
#             "compound_code" : "VFRP+F3 Eden Prairie, Minnesota",
#             "global_code" : "86P8VFRP+F3"
#          },
#          "price_level" : 1,
#          "rating" : 4.7,
#          "reference" : "ChIJEzS3cz4c9ocRjQCr5VIjFwA",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 681,
#          "vicinity" : "6207 Dell Rd, Eden Prairie"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9703408,
#                "lng" : -93.1061584
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97163572989272,
#                   "lng" : -93.10475027010727
#                },
#                "southwest" : {
#                   "lat" : 44.96893607010728,
#                   "lng" : -93.10744992989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Mama's Pizza",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101763634573589302930\"\u003eJacob Welti\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRiCbJcEtsK9jUaBRzl6DTnfg7IdXZVGY9vl7eCPznzuxaFJZD0i7-vu3uMgfAn4qQ-ELwg2Onp6iAbeh71dyPvGRSOdFoho-Kr8kVRS1p_yXEoZEvFa5kJMoEp9TwvQ85GvNDCTwj4j4VektDD4TOWQOFk_nOMw4xxRuAq28C8A2Cgi",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJf_edW6Qqs1IRJJHbOBER0_g",
#          "plus_code" : {
#             "compound_code" : "XVCV+4G St Paul, Minnesota",
#             "global_code" : "86P8XVCV+4G"
#          },
#          "price_level" : 1,
#          "rating" : 4.8,
#          "reference" : "ChIJf_edW6Qqs1IRJJHbOBER0_g",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 1805,
#          "vicinity" : "961 Rice St, St Paul"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8691892,
#                "lng" : -93.4566298
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.87058407989272,
#                   "lng" : -93.45517227010728
#                },
#                "southwest" : {
#                   "lat" : 44.86788442010727,
#                   "lng" : -93.45787192989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Gina Maria's Pizza",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 1960,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/100058791830811887107\"\u003eSeth Peake\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRg51wD0zk5xstO6mZpvNhgyvADxIXq_DlAes9ICrrSHwI_sB9QKLxjMpQvbyfW0Y5iRHS-JXMovqzcZE2LzNJkJIm4O7YZ3NehTzc8WsBnZPQtVbJ5oMvByuMAXNjOXDqh8W9xPoN1-MJ0U1EuygTDj45iP2a5_3fTBabNqS4Q-LtNA",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJA-uOINQY9ocRTAWKcur8J-o",
#          "plus_code" : {
#             "compound_code" : "VG9V+M8 Eden Prairie, Minnesota",
#             "global_code" : "86P8VG9V+M8"
#          },
#          "price_level" : 2,
#          "rating" : 4.5,
#          "reference" : "ChIJA-uOINQY9ocRTAWKcur8J-o",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 418,
#          "vicinity" : "7416 Mitchell Rd, Eden Prairie"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.946746,
#                "lng" : -93.15023699999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.94807012989272,
#                   "lng" : -93.14888747010727
#                },
#                "southwest" : {
#                   "lat" : 44.94537047010728,
#                   "lng" : -93.15158712989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizza Lucé St Paul",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 2848,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/114934196829090306345\"\u003ePizza Luce\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRjAXvHM91g8rQSXAnMPEtd5TW8nLesQP9MOiTjl6SmBxdbSYQMN70yNH01uhdyxblMpPeCa7ZyEneQqHdeJl2OH11bAdobeIEPxG_x5oRXJTAyabaNwafq4TpUdDsw_0cxcwoJk2Q9uDnPZBJp_mJ9vcMLUlS2C77TGeExOJlcf8HzA",
#                "width" : 4288
#             }
#          ],
#          "place_id" : "ChIJs3rc0m8q9ocRYpogcbkGJQY",
#          "plus_code" : {
#             "compound_code" : "WRWX+PW St Paul, Minnesota",
#             "global_code" : "86P8WRWX+PW"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJs3rc0m8q9ocRYpogcbkGJQY",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 1623,
#          "vicinity" : "1183 Selby Ave, St Paul"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9008354,
#                "lng" : -93.2476934
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.90224327989272,
#                   "lng" : -93.24647722010728
#                },
#                "southwest" : {
#                   "lat" : 44.89954362010727,
#                   "lng" : -93.24917687989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Fat Lorenzos",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/112816908376090843862\"\u003eJose Garcia\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRjTlODBlCz_KmH0K2-w7nbC_b2sVM2u6setGjlJxF_dP3r41QdZGHJJISqiQBJeNtX9lr_6jo37SUd9g9MCOfbEATGW8gGQvFJjTcu7moNIenm-MFOPpTzxlGked8eOqxCzIRc6j3yc8CN4ZprjJwIWcp3ZpwyG1HjalwG2sM0WbYpE",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJQdxqe5co9ocRtpNpifHDHgA",
#          "plus_code" : {
#             "compound_code" : "WQ22+8W Minneapolis, Minnesota",
#             "global_code" : "86P8WQ22+8W"
#          },
#          "price_level" : 2,
#          "rating" : 4.5,
#          "reference" : "ChIJQdxqe5co9ocRtpNpifHDHgA",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 2098,
#          "vicinity" : "5600 Cedar Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.94451129999999,
#                "lng" : -93.28874209999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.94586997989272,
#                   "lng" : -93.28727252010728
#                },
#                "southwest" : {
#                   "lat" : 44.94317032010728,
#                   "lng" : -93.28997217989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizza Lucé Uptown",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3036,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110896687875114775720\"\u003eJulie Markfort\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRjFaCF1-0fRl3U1MnbfcKIZCZc96qCLVEuapQl_qojPm_NZcoqzS6YfU19ubgalY9UGNMCKdPdAtNJ36bEPycgRfFtQaD5-VxYYpjHooWWG0iF-5tYee_C-V6rm0JTvMOTSyAfbSgTwpzt3cUMplZgEwPOYLaihbZxyZ9wQkQ18BVuI",
#                "width" : 4048
#             }
#          ],
#          "place_id" : "ChIJVUyL9I8n9ocRdUQiHwSrfBg",
#          "plus_code" : {
#             "compound_code" : "WPV6+RG Minneapolis, Minnesota",
#             "global_code" : "86P8WPV6+RG"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJVUyL9I8n9ocRdUQiHwSrfBg",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 1606,
#          "vicinity" : "3200 Lyndale Ave S, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9808059,
#                "lng" : -93.23614309999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.98212457989272,
#                   "lng" : -93.23481722010727
#                },
#                "southwest" : {
#                   "lat" : 44.97942492010728,
#                   "lng" : -93.23751687989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Mesa Pizza Dinkytown",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 2269,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103807491434409087346\"\u003eMesa Pizza Dinkytown\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRi5h6uEPaCZH9m0VKM5Q2L4tN-PmyVzvSaSQAMbqcibncpBDHRowm6DRBJXSRvGnnSWGvvlsxqAlN8RGycWKpzDeQNG0ci0Cp4qSzoXJjWMZIzNMxiPK1e6dvUo-LkTMDQnDfklRoK6-Z8mYb5eS_wDZAVQS409ciF20IUquYMqz2PD",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJLaEvihEts1IRA93dH4Hw8DM",
#          "plus_code" : {
#             "compound_code" : "XQJ7+9H Minneapolis, Minnesota",
#             "global_code" : "86P8XQJ7+9H"
#          },
#          "price_level" : 1,
#          "rating" : 4.4,
#          "reference" : "ChIJLaEvihEts1IRA93dH4Hw8DM",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "restaurant",
#             "point_of_interest",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 761,
#          "vicinity" : "1323 4th St SE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9163624,
#                "lng" : -93.2627995
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.91771122989272,
#                   "lng" : -93.26139677010727
#                },
#                "southwest" : {
#                   "lat" : 44.91501157010728,
#                   "lng" : -93.26409642989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pizza Biga",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107588262581121544777\"\u003eMichael Santangelo\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRjEePnvO336YQhL_cNDFoxO50pwR5IGMTliQVkbMH4pOkmCFdqwgru5bvqcd-fDYeKDV9RQpKOgr0R6GIFu1qvP5oM9KfZmkowdCjWi668UygBASHLllz0y8yGAuba7cwUiZYNC0AfuWltK6tIJgH4wTdEYSB2lrFfMmLYkU_eJgS4R",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJQ3UcrdQn9ocRD_FcBXAc3S8",
#          "plus_code" : {
#             "compound_code" : "WP8P+GV Minneapolis, Minnesota",
#             "global_code" : "86P8WP8P+GV"
#          },
#          "rating" : 4.6,
#          "reference" : "ChIJQ3UcrdQn9ocRD_FcBXAc3S8",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 95,
#          "vicinity" : "4762 Chicago Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9727085,
#                "lng" : -93.0732237
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97405382989272,
#                   "lng" : -93.07202297010727
#                },
#                "southwest" : {
#                   "lat" : 44.97135417010728,
#                   "lng" : -93.07472262989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Eastside Pizzeria",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 4640,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105950979417298207665\"\u003eSavage Vinmiller\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgNlPnz7eNcmkrVWLZerxxvDmGjg4nGAi9ghlbLn1T-KaEh9a43ZCyDjPC4Ai0p_p5419W_IWK_DmDlt15H9bKJFMshfubCx2gz-BmnmMxFlncKpx3iD0dPTEBpermMXdcEeXPrcqDs4dWuyrLgI5QnNPR2OLXXkoVLtnJyUWBxDuBo",
#                "width" : 3480
#             }
#          ],
#          "place_id" : "ChIJETN_993UslIRDAuIEsvhBv4",
#          "plus_code" : {
#             "compound_code" : "XWFG+3P St Paul, Minnesota",
#             "global_code" : "86P8XWFG+3P"
#          },
#          "price_level" : 1,
#          "rating" : 4.5,
#          "reference" : "ChIJETN_993UslIRDAuIEsvhBv4",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "meal_takeaway",
#             "restaurant",
#             "point_of_interest",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 839,
#          "vicinity" : "1050 Payne Ave, St Paul"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9235001,
#                "lng" : -93.2165619
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.92483642989272,
#                   "lng" : -93.21527762010729
#                },
#                "southwest" : {
#                   "lat" : 44.92213677010727,
#                   "lng" : -93.21797727989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Parkway Pizza",
#          "photos" : [
#             {
#                "height" : 9000,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/104833440604263989554\"\u003eGreta Kirckof\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhMtLSeTlfZd-Yj3HCbjsh0G3HfIBSMY7Lvc0sD-OUDaoPJQULMkaERcw8mogq0HqnGZ5JRlha85GJ4qnS2Wyzwmk0PCkdG9MPtfz7WbvyszVqEYL_myuqAUAfYMZ9XjxlXWUhwUNJyfYvNBq71Hke6h4jZtW4dncizGaeemHKgr5Sd",
#                "width" : 12000
#             }
#          ],
#          "place_id" : "ChIJK-MGUKkp9ocRcWmCjUaoE2o",
#          "plus_code" : {
#             "compound_code" : "WQFM+CC Minneapolis, Minnesota",
#             "global_code" : "86P8WQFM+CC"
#          },
#          "price_level" : 2,
#          "rating" : 4.6,
#          "reference" : "ChIJK-MGUKkp9ocRcWmCjUaoE2o",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 1087,
#          "vicinity" : "4359 Minnehaha Ave, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.9566612,
#                "lng" : -93.1672607
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.95798717989272,
#                   "lng" : -93.16591562010727
#                },
#                "southwest" : {
#                   "lat" : 44.95528752010728,
#                   "lng" : -93.16861527989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Checker Board Pizza",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117333922776862394741\"\u003eMcCallion Stark\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRj08uY69O-QAmkbNgdzRt2clpsqbm6iaYsYQjfVmRLZ_kOTNIK1hRA9uARoKq9OKuOvGQnfcc3x3MSOouUxstsKf3Kz3urdFOeWZBS0Hj65CXQ91ThlV2cI1s_yOnMv1MfRbk_GwPKIhpWgj8ES2TrekbyE7ibfKeLix_Y5KT0d_cw",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJp6iyT00rs1IR9L2GJvHLEH8",
#          "plus_code" : {
#             "compound_code" : "XR4M+M3 St Paul, Minnesota",
#             "global_code" : "86P8XR4M+M3"
#          },
#          "price_level" : 1,
#          "rating" : 4.4,
#          "reference" : "ChIJp6iyT00rs1IR9L2GJvHLEH8",
#          "scope" : "GOOGLE",
#          "types" : [
#             "meal_delivery",
#             "restaurant",
#             "point_of_interest",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 603,
#          "vicinity" : "511 Snelling Ave, St Paul"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 45.0201966,
#                "lng" : -93.23697159999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.02154122989272,
#                   "lng" : -93.23569327010728
#                },
#                "southwest" : {
#                   "lat" : 45.01884157010727,
#                   "lng" : -93.23839292989273
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Parkway Pizza",
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107813869947908108868\"\u003eJesse\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRiNAIkzaJjqwdChkXx0WD0hKTIB5xah5JsGmqp2myWqBnCAk9gSqM4hVLC2E5hC7ab1RquwdHcBnlMQPmRDWbTuDbajZvc-bjQjSIUgL68g87UaL57HSVfzuCLFIT_Dc5-tvi0MDcZSbpOo6XFrr4O15CqLwhB_e1AyLRuHzqv3q2wQ",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJRQfYx9ots1IRzNxr4uLWoeU",
#          "plus_code" : {
#             "compound_code" : "2QC7+36 Minneapolis, Minnesota",
#             "global_code" : "86Q82QC7+36"
#          },
#          "price_level" : 2,
#          "rating" : 4.5,
#          "reference" : "ChIJRQfYx9ots1IRzNxr4uLWoeU",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 429,
#          "vicinity" : "2851 Johnson St NE, Minneapolis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8806309,
#                "lng" : -93.32520149999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.88186247989272,
#                   "lng" : -93.32393837010727
#                },
#                "southwest" : {
#                   "lat" : 44.87916282010728,
#                   "lng" : -93.32663802989272
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "DeLeo Bros. Pizza",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 1363,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/102465783658036530387\"\u003eDeLeo Bros. Pizza\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRgwoWkbMoBb0OTfWqzoc-QI5M05jZ7axIKJZazetJks5H0w1wGlFoE97JBJdtNycoFBidaUUNMdheC0oklybHffthPZd01N7bb2Fk-LWcHk9PQuM9a4YXNTcek6Uk_ftinmjYVLbU1LTMZFkrNuYw-Mpz2UmDutGG6urXvy5wBaBbjK",
#                "width" : 2048
#             }
#          ],
#          "place_id" : "ChIJZwaB_aYm9ocRMQqUx0rOggI",
#          "plus_code" : {
#             "compound_code" : "VMJF+7W Edina, Minnesota",
#             "global_code" : "86P8VMJF+7W"
#          },
#          "price_level" : 1,
#          "rating" : 4.6,
#          "reference" : "ChIJZwaB_aYm9ocRMQqUx0rOggI",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 684,
#          "vicinity" : "1705 Southdale Ctr, Edina"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8676773,
#                "lng" : -93.43746949999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.86904672989272,
#                   "lng" : -93.43663557010727
#                },
#                "southwest" : {
#                   "lat" : 44.86634707010727,
#                   "lng" : -93.43933522989271
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Chalet Pizza",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/114579291324350385781\"\u003eMatthew Gantz\u003c/a\u003e"
#                ],
#                "photo_reference" : "AcYSjRhyOgWxrMzCNIShbmExU2l5ZX6rbnZk5pKhP1u9fqpXjd09NMNpUJwtnEvdsUjtZRi78YvavcXpoNEbg89zGZK6iGBqHuDphF8w_U4bVlESmZ_Gv4fLrZ5a2NIPKH5Hf-YSPtpufwL4orfRXb3g4jqVVpSFmE58L3Xi_jd4HN55dMJo",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJPyILfo4f9ocRq0sJbjKNXaE",
#          "plus_code" : {
#             "compound_code" : "VH97+32 Eden Prairie, Minnesota",
#             "global_code" : "86P8VH97+32"
#          },
#          "price_level" : 1,
#          "rating" : 4.6,
#          "reference" : "ChIJPyILfo4f9ocRq0sJbjKNXaE",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "point_of_interest", "food", "establishment" ],
#          "user_ratings_total" : 148,
#          "vicinity" : "12617 Valley View Rd, Eden Prairie"
#       }
#    ],
#    "status" : "OK"
# }

# %%
import pandas
import json
r_json=response.json()["results"]

# %%
df=pandas.DataFrame(columns=("Name", "Latitude","Longitude"))

for feature in range(len(r_json)):
    name=[r_json[feature]["name"]]
    Latitude=[r_json[feature]["geometry"]["location"]["lat"]]
    Longitude=[r_json[feature]["geometry"]["location"]["lng"]]
    
    df.loc[feature]=name+Latitude+Longitude
    
df.head()
# Out:
#                          Name   Latitude  Longitude
# 0               Pizzeria Lola  44.901815 -93.318600
# 1            Station Pizzeria  44.941610 -93.444437
# 2                 Pizza Flame  45.158502 -93.318756
# 3  Pizza Karma - Eden Prairie  44.850408 -93.431528
# 4                 Blaze Pizza  44.973525 -93.223528
