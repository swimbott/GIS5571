# %% [markdown]
# ## extract google spaces api

# %%
import requests
import pandas
import json

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.991192%2C-93.260567&radius=2500&type=restaurant&keyword=subs&key=AIzaSyAOnstvDO861Lpg-4Jw8LlWWEaXEflkQ-4"

# restaurant/sub stations in mlps

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "AcYSjRhsu3aGxUIHvLBp4Fz1GwOnaVe42UMCCrsn4JyFxViGg85qkI5qscghbOi3vgTmAoO3yO_lRISP-X1LNeqCCb248-31oTyShyKs3n81cteDZzCSsW2V8aUYB2uxf609Pf70hdQdo0BME1TVWI4jB3GAj25x4snB9Vs3i4wEnZnruIeoMpbe86h7ng26-Z0MxogBVWPQs0-T89NfnYgf5_TzUXp_NJzs5y06pLG70duFphcf2sih8A-1AJGMrQ7JvxvOjiX__XLpyz5l2Uout3gIayRNBa_1b7_D1I3JJP_OFDS-cmTOHk9njQI6h_kKAM-CTLLMNnw2sn1g52AmN7ftt1A9Mqr_bk9A_7Pqgo0stWR22FWSzTwFZdNR9CFIa6VVD0mtvsEazi7CcAz879H3_w85a3w0Eqx9RBnu-V2JsjWFjANtG0K9MhZRXTYfvYBl",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.97618629999999,
#                "lng" : -93.27190450000001
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.97774397989272,
#                   "lng" : -93.27036847010729
#                },
#                "southwest" : {
# ...

# %%
r_json_restaurants=response.json()["results"]

# %%
df_restaurants=pandas.DataFrame(columns=("Name", "Latitude","Longitude"))

for feature in range(len(r_json_restaurants)):
    name=[r_json_restaurants[feature]["name"]]
    Latitude=[r_json_restaurants[feature]["geometry"]["location"]["lat"]]
    Longitude=[r_json_restaurants[feature]["geometry"]["location"]["lng"]]
    
    df_restaurants.loc[feature]=name+Latitude+Longitude
    
df_restaurants.head()
# Out:
#                   Name   Latitude  Longitude
# 0             Potbelly  44.976186 -93.271905
# 1         Jimmy John's  44.979011 -93.274550
# 2         Jimmy John's  44.977106 -93.267702
# 3         Jimmy John's  44.980650 -93.235466
# 4  Erbert and Gerberts  45.005593 -93.228217

# %% [markdown]
# # getting in sub data

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.991192%2C-93.260567&radius=25000&type=restaurant&keyword=pizza&key=AIzaSyBMKRI1bK3qW5KWmb1ZD1erCZ0f9yUEAEk"

# pizza places in mlps

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "AcYSjRjNVUvYQ6cUCsoMg9fjrIhTFiq3uBKcyqQxFmkc-B9GlXFICjgP1zegUrddCHoEoUdUm_xJFnIb4Isus0GOPWf8Iv7C07EjE1GPbJ36iWTse6Oazyl7pRN_QcMvQoDHVljBX4vUpRBEa4UMrPGrTDMHJeNaYbeNzlUY14l0Kt3phZqKRxPJKkyYrcgbm6Af9LIX-XYrsubl4r0ryDjggIYM0VVfOtp3kSFfn9I6w1FEwu5oO28lZGLlCbWmPRQMwDVKMCD_7lP3XJRng4jpquFHY3ulvFC6vYdKgt2GwKZ1RlkBaSa4j11nBNHHGdpNP4m6N4SUgmq0TmbfD6I8NAUGr4bndtkEdWPOoVeIMbbfUoxlbFNZhl2ciZwZK4io_dSBnbXJryHgvl4IPgp1bkR9xatF1Eocx33o9Ipng4Aur7nNAGZcembcRpBQ5ghlU3TqMA",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.901815,
#                "lng" : -93.3185998
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.90316827989272,
#                   "lng" : -93.31736697010729
#                },
#                "southwest" : {
#                   "lat" : 44.90046862010728,
# ...

# %%
r_json=response.json()["results"]

# %%
df=pandas.DataFrame(columns=("Name", "Latitude","Longitude"))

for feature in range(len(r_json)):
    name=[r_json[feature]["name"]]
    Latitude=[r_json[feature]["geometry"]["location"]["lat"]]
    Longitude=[r_json[feature]["geometry"]["location"]["lng"]]
    
    df.loc[feature]=name+Latitude+Longitude
    
df.head()
# Out:
#                   Name   Latitude  Longitude
# 0        Pizzeria Lola  44.901815 -93.318600
# 1     Station Pizzeria  44.941610 -93.444437
# 2          Pizza Flame  45.158502 -93.318756
# 3          Blaze Pizza  44.973525 -93.223528
# 4  Pizza Lucé Downtown  44.981756 -93.273552

# %%
df.head
# Out:
# <bound method NDFrame.head of                           Name   Latitude  Longitude
# 0                Pizzeria Lola  44.901815 -93.318600
# 1             Station Pizzeria  44.941610 -93.444437
# 2                  Pizza Flame  45.158502 -93.318756
# 3                  Blaze Pizza  44.973525 -93.223528
# 4          Pizza Lucé Downtown  44.981756 -93.273552
# 5      Detello's Pizza & Pasta  44.891182 -93.514931
# 6                 Mama's Pizza  44.970341 -93.106158
# 7           Gina Maria's Pizza  44.869189 -93.456630
# 8                 Fat Lorenzos  44.900835 -93.247693
# 9           Pizza Lucé St Paul  44.946814 -93.150236
# 10           Pizza Lucé Uptown  44.944511 -93.288742
# 11        Mesa Pizza Dinkytown  44.980806 -93.236143
# 12                  Pizza Biga  44.916362 -93.262799
# 13           Eastside Pizzeria  44.972709 -93.073224
# 14  Pizza Karma - Eden Prairie  44.850408 -93.431528
# 15               Parkway Pizza  44.923500 -93.216562
# ...

# %%
import pandas as pd
import geopandas ## I was able to import geopandas on a juypter notebook and this process worked
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# In  [8]:
# Line 2:     import geopandas ## I was able to import geopandas on a juypter notebook and this process worked
#
# ModuleNotFoundError: No module named 'geopandas'
# ---------------------------------------------------------------------------

# %%
# projecting pizza data to get into right crs
arcpy.management.Project("df", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\pizza", 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', None, 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', "NO_PRESERVE_SHAPE", None, "NO_VERTICAL")

# projecting sub data to get into right crs
arcpy.management.Project("df_restaurants", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\subs", 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', None, 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', "NO_PRESERVE_SHAPE", None, "NO_VERTICAL")
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [9]:
# ...

# %%
## Getting data frame into geodata frame 
gdf_pizza = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))
print(gdf_pizza.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [10]:
# Line 2:     gdf_pizza = geopandas.GeoDataFrame(
#
# NameError: name 'geopandas' is not defined
# ---------------------------------------------------------------------------

# %%
## Getting data frame into geodata frame 
gdf_subs = geopandas.GeoDataFrame(
    df_restaurants, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))
print(gdf_subs.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [11]:
# Line 2:     gdf_subs = geopandas.GeoDataFrame(
#
# NameError: name 'geopandas' is not defined
# ---------------------------------------------------------------------------

# %%
# spatial join # this is if I had geopandas..
subs_pizza_sj = geopandas.sjoin(gdf_pizza, gdf_subs, how="inner", op='within')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [12]:
# Line 2:     subs_pizza_sj = geopandas.sjoin(gdf_pizza, gdf_subs, how="inner", op='within')
#
# NameError: name 'geopandas' is not defined
# ---------------------------------------------------------------------------

# %%
# my other option using arcpy
arcpy.analysis.SpatialJoin("subs", "pizza", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\subs_pizza_SpatialJoin", "JOIN_ONE_TO_ONE", "KEEP_ALL", 'id "id" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,id,-1,-1;start_date "start_date" true true false 8 Date 0 0,First,#,wildfires_tracked_by_mndnr,start_date,-1,-1;start_time "start_time" true true false 65536 Text 0 0,First,#,wildfires_tracked_by_mndnr,start_time,0,65536;acres_f "acres_f" true true false 8 Double 0 0,First,#,wildfires_tracked_by_mndnr,acres_f,-1,-1;acres_nf "acres_nf" true true false 8 Double 0 0,First,#,wildfires_tracked_by_mndnr,acres_nf,-1,-1;acres_tot "acres_tot" true true false 8 Double 0 0,First,#,wildfires_tracked_by_mndnr,acres_tot,-1,-1;size_class "size_class" true true false 12 Text 0 0,First,#,wildfires_tracked_by_mndnr,size_class,0,12;county "county" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,county,0,100;section "section" true true false 2 Text 0 0,First,#,wildfires_tracked_by_mndnr,section,0,2;township "township" true true false 3 Text 0 0,First,#,wildfires_tracked_by_mndnr,township,0,3;range "range" true true false 2 Text 0 0,First,#,wildfires_tracked_by_mndnr,range,0,2;range_dir "range_dir" true true false 1 Text 0 0,First,#,wildfires_tracked_by_mndnr,range_dir,0,1;cause "cause" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,cause,0,100;permit "permit" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,permit,-1,-1;injuries "injuries" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,injuries,-1,-1;fatalities "fatalities" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,fatalities,-1,-1;l_timber "l_timber" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_timber,-1,-1;l_agri "l_agri" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_agri,-1,-1;l_personal "l_personal" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_personal,-1,-1;l_other "l_other" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_other,-1,-1;l_res_dam "l_res_dam" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_res_dam,-1,-1;l_res_des "l_res_des" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_res_des,-1,-1;l_out_dam "l_out_dam" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_out_dam,-1,-1;l_out_des "l_out_des" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_out_des,-1,-1;i_rpt_by "i_rpt_by" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,i_rpt_by,0,100;status "status" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,status,0,100;key_year "key_year" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,key_year,-1,-1;id_1 "id" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,id,-1,-1;start_date_1 "start_date" true true false 8 Date 0 0,First,#,wildfires_tracked_by_mndnr,start_date,-1,-1;start_time_1 "start_time" true true false 65536 Text 0 0,First,#,wildfires_tracked_by_mndnr,start_time,0,65536;acres_f_1 "acres_f" true true false 8 Double 0 0,First,#,wildfires_tracked_by_mndnr,acres_f,-1,-1;acres_nf_1 "acres_nf" true true false 8 Double 0 0,First,#,wildfires_tracked_by_mndnr,acres_nf,-1,-1;acres_tot_1 "acres_tot" true true false 8 Double 0 0,First,#,wildfires_tracked_by_mndnr,acres_tot,-1,-1;size_class_1 "size_class" true true false 12 Text 0 0,First,#,wildfires_tracked_by_mndnr,size_class,0,12;county_1 "county" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,county,0,100;section_1 "section" true true false 2 Text 0 0,First,#,wildfires_tracked_by_mndnr,section,0,2;township_1 "township" true true false 3 Text 0 0,First,#,wildfires_tracked_by_mndnr,township,0,3;range_1 "range" true true false 2 Text 0 0,First,#,wildfires_tracked_by_mndnr,range,0,2;range_dir_1 "range_dir" true true false 1 Text 0 0,First,#,subs,range_dir,0,1;cause_1 "cause" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,cause,0,100;permit_1 "permit" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,permit,-1,-1;injuries_1 "injuries" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,injuries,-1,-1;fatalities_1 "fatalities" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,fatalities,-1,-1;l_timber_1 "l_timber" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_timber,-1,-1;l_agri_1 "l_agri" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_agri,-1,-1;l_personal_1 "l_personal" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_personal,-1,-1;l_other_1 "l_other" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_other,-1,-1;l_res_dam_1 "l_res_dam" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_res_dam,-1,-1;l_res_des_1 "l_res_des" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_res_des,-1,-1;l_out_dam_1 "l_out_dam" true true false 4 Long 0 0,First,#,wildfires_tracked_by_mndnr,l_out_dam,-1,-1;l_out_des_1 "l_out_des" true true false 4 Long 0 0,First,#,subs,l_out_des,-1,-1;i_rpt_by_1 "i_rpt_by" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,i_rpt_by,0,100;status_1 "status" true true false 100 Text 0 0,First,#,wildfires_tracked_by_mndnr,status,0,100;key_year_1 "key_year" true true false 4 Long 0 0,First,#,subs,-1,-1', "INTERSECT", None, '')
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [13]:
# ...

# %%
arcpy.env.workspace = r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb'

# %%
# !curl https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dot/bdry_state/shp_bdry_state.zip -o "mn_counties.zip”
# Out:
# curl: (3) URL using bad/illegal format or missing URL

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0E46-DC76
#
#  Directory of C:\windows\system32
#
# 10/05/2022  05:31 PM    <DIR>          .
# 10/04/2022  11:32 PM    <DIR>          ..
# 06/05/2021  08:09 AM    <DIR>          0409
# 06/05/2021  07:05 AM            24,912 0ae3b998-9a38-4b72-a4c4-06849441518d_Servicing-Stack.dll
# 08/03/2022  11:56 AM    <DIR>          1028
# 08/03/2022  11:56 AM    <DIR>          1029
# 08/03/2022  11:56 AM    <DIR>          1031
# 08/03/2022  11:56 AM    <DIR>          1033
# 08/03/2022  11:56 AM    <DIR>          1036
# 08/03/2022  11:56 AM    <DIR>          1040
# 08/03/2022  11:56 AM    <DIR>          1041
# 08/03/2022  11:56 AM    <DIR>          1042
# 08/03/2022  11:56 AM    <DIR>          1045
# 08/03/2022  11:56 AM    <DIR>          1046
# 08/03/2022  11:56 AM    <DIR>          1049
# 08/03/2022  11:56 AM    <DIR>          1055
# 08/03/2022  11:56 AM    <DIR>          2052
# 08/03/2022  11:56 AM    <DIR>          3082
# ...

# %% [markdown]
# ## MN geospatial commons api

# %%
import arcpy
import requests
import zipfile
import io

# %%
arcpy.env.workspace = r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb'

# %% [markdown]
# bringing in the water supply data

# %%
response_API = requests.get("https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_health/water_drinking_water_supply/shp_water_drinking_water_supply.zip")
print(response.status_code)
# Out:
# 200

# %%
data = response_API.text

# %%
download_link = r'https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_health/water_drinking_water_supply/shp_water_drinking_water_supply.zip'

# %%
output = requests.post(download_link)

# %%
requestcontent = output.content

# %%
zip_watersupply = zipfile.ZipFile(io.BytesIO(requestcontent))

# %%
zip_watersupply.extractall(r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\watersupply')

# %% [markdown]
# bringing in the wild rice lakes

# %%
wildrice_link = r'https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/biota_wild_rice_lakes_dnr_wld/'

# %%
req_object = requests.get(wildrice_link)

# %%
req_object.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<html>\n <head>\n  <title>Index of /pub/gdrs/data/pub/us_mn_state_dnr/biota_wild_rice_lakes_dnr_wld</title>\n </head>\n <body>\n<h1>Index of /pub/gdrs/data/pub/us_mn_state_dnr/biota_wild_rice_lakes_dnr_wld</h1>\n<table><tr><th><img src="/icons/blank.gif" alt="[ICO]"></th><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr><tr><th colspan="5"><hr></th></tr>\n<tr><td valign="top"><img src="/icons/back.gif" alt="[DIR]"></td><td><a href="/pub/gdrs/data/pub/us_mn_state_dnr/">Parent Directory</a></td><td>&nbsp;</td><td align="right">  - </td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/text.gif" alt="[TXT]"></td><td><a href="dataResource.xml">dataResource.xml</a></td><td align="right">01-Sep-2022 02:36  </td><td align="right">1.7K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/compressed.gi
# ...

# %%
q = requests.get(wildrice_link)

# %%
q.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<html>\n <head>\n  <title>Index of /pub/gdrs/data/pub/us_mn_state_dnr/biota_wild_rice_lakes_dnr_wld</title>\n </head>\n <body>\n<h1>Index of /pub/gdrs/data/pub/us_mn_state_dnr/biota_wild_rice_lakes_dnr_wld</h1>\n<table><tr><th><img src="/icons/blank.gif" alt="[ICO]"></th><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr><tr><th colspan="5"><hr></th></tr>\n<tr><td valign="top"><img src="/icons/back.gif" alt="[DIR]"></td><td><a href="/pub/gdrs/data/pub/us_mn_state_dnr/">Parent Directory</a></td><td>&nbsp;</td><td align="right">  - </td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/text.gif" alt="[TXT]"></td><td><a href="dataResource.xml">dataResource.xml</a></td><td align="right">01-Sep-2022 02:36  </td><td align="right">1.7K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/compressed.gi
# ...

# %%
download_link_wildrice = r'https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/biota_wild_rice_lakes_dnr_wld/shp_biota_wild_rice_lakes_dnr_wld.zip'

# %%
output_wildrice = requests.post(download_link_wildrice)

# %%
stuff_wildrice = output_wildrice.content

# %%
zip_wildrice = zipfile.ZipFile(io.BytesIO(stuff_wildrice))

# %%
zip_wildrice.extractall(r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces')

# %%
wildrice_location = pd.read_csv('C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape (<string>, line 1)
# ---------------------------------------------------------------------------

# %%
watersupply_location = pd.read_csv('C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape (<string>, line 1)
# ---------------------------------------------------------------------------

# %%
# get projection the same
arcpy.management.Project("wildrice_location", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\wildrice", 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', None, 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', "NO_PRESERVE_SHAPE", None, "NO_VERTICAL")
arcpy.management.Project("watersupply_location", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\watersupply_location", 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', None, 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', "NO_PRESERVE_SHAPE", None, "NO_VERTICAL")
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [38]:
# ...

# %%
# spatial join
arcpy.analysis.SpatialJoin("wildrice_location", "watersupply_location", "watersupply_wildrice_sj")
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [39]:
# Line 2:     arcpy.analysis.SpatialJoin("wildrice_location", "watersupply_location", "watersupply_wildrice_sj")
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\analysis.py, in SpatialJoin:
# Line 793:   raise e
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\analysis.py, in SpatialJoin:
# Line 790:   retval = convertArcObjectToPythonObject(gp.SpatialJoin_analysis(*gp_fixargs((target_features, join_features, out_feature_class, join_operation, join_type, field_mapping, match_option, search_radius, distance_field_name), True)))
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 512:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: Failed to execute. Parameters are not valid.
# ...

# %%
# show the spatially joined attributes
watersupply_wildrice_sj.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [40]:
# Line 2:     watersupply_wildrice_sj.head()
#
# NameError: name 'watersupply_wildrice_sj' is not defined
# ---------------------------------------------------------------------------

# %% [markdown]
# # extract ndawn api

# %%
import arcpy
import requests
import zipfile
import io
import pandas as pd

# %%
arcpy.env.workspace = r'C:\Users\swimb\Documents\ArcGIS\Projects\Ndawn\Ndawn.gdb'

# %%
# bring in weekly max temps
url = 'https://ndawn.ndsu.nodak.edu/table.csv?station=78&variable=ddmxt&year=2022&ttype=daily&quick_pick=7_d&begin_date=2022-10-04&end_date=2022-10-04'

# %%
r = requests.get(url)

# %%
download_link_airtempmax = 'https://ndawn.ndsu.nodak.edu/table.csv?station=78&variable=ddmxt&year=2022&ttype=daily&quick_pick=7_d&begin_date=2022-10-04&end_date=2022-10-04'

# %%
download_link_airtemp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [46]:
# Line 1:     download_link_airtemp
#
# NameError: name 'download_link_airtemp' is not defined
# ---------------------------------------------------------------------------

# %%
output = requests.post(download_link_airtemp)

# %%
slashstuff = output.content

# %%
ndawn_base_url = "https://ndawn.ndsu.nodak.edu/table.csv"

ndawn_parameters = {
    "station" : "78",
    "variable" : "ddmnt",
    "dfn" : "",
    "year" : "2022"
    "ttype" : "daily",
    "quick_pick" : "7",
    "begin_date" : "2022-10-08",
    "end_date" : "2022-10-08",
    "count" : "12"}
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: invalid syntax (<string>, line 8)
# ---------------------------------------------------------------------------

# %%
req_respone = requests.get(download_link_airtemp, params = master_params)

with open("airtempmaxcsv.csv", "w") as newCSV_txt:
    newCSV_txt.write(req_response.content.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: unexpected EOF while parsing (<string>, line 4)
# ---------------------------------------------------------------------------

# %%
show_airtemp = pd.read_csv('airtempmax.csv', skiprows = 3)
show_airtemp.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# In  [50]:
# Line 1:     show_airtemp = pd.read_csv('airtempmax.csv', skiprows = 3)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\util\_decorators.py, in wrapper:
# Line 311:   return func(*args, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in read_csv:
# Line 586:   return _read(filepath_or_buffer, kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in _read:
# Line 482:   parser = TextFileReader(filepath_or_buffer, **kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in __init__:
# Line 811:   self._engine = self._make_engine(self.engine)
#
# ...

# %%
input_features = r'C:\Users\swimb\Documents\ArcGIS\Projects\Ndawn\Ndawn.gdb'

# %%
import numpy

# %%
df = pd.read_csv(r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\weedlymaxtemp.csv')
print (df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# In  [53]:
# Line 1:     df = pd.read_csv(r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\weedlymaxtemp.csv')
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\util\_decorators.py, in wrapper:
# Line 311:   return func(*args, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in read_csv:
# Line 586:   return _read(filepath_or_buffer, kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in _read:
# Line 482:   parser = TextFileReader(filepath_or_buffer, **kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in __init__:
# Line 811:   self._engine = self._make_engine(self.engine)
# ...

# %%
# bring in weekly min temp

# %%
arcpy.env.workspace = r'C:\Users\swimb\Documents\ArcGIS\Projects\Ndawn\Ndawn.gdb'

# %%
url_max = 'https://ndawn.ndsu.nodak.edu/weather-data-weekly.html#'

# %%
r_min = requests.get(url)

# %%
download_link_airtempmin = 'https://ndawn.ndsu.nodak.edu/weather-data-weekly.html#'
download_link_airtempmin
# Out:
# 'https://ndawn.ndsu.nodak.edu/weather-data-weekly.html#'

# %%
output = requests.post(download_link_airtempmin)

# %%
slashstuff = output.content

# %%
ndawn_base_url = "https://ndawn.ndsu.nodak.edu/table.csv"

ndawn_parameters = {
    "station" : "78",
    "variable" : "ddmxt",
    "dfn" : "",
    "year" : "2022"
    "ttype" : "daily",
    "quick_pick" : "7",
    "begin_date" : "2022-10-08",
    "end_date" : "2022-10-08",
    "count" : "12"}
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: invalid syntax (<string>, line 8)
# ---------------------------------------------------------------------------

# %%
req_respone = requests.get(download_link_airtempmin, params = master_params)

with open("airtempmincsv.csv", "w") as newCSV_txt:
    newCSV_txt.write(req_response.content.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: unexpected EOF while parsing (<string>, line 4)
# ---------------------------------------------------------------------------

# %%
show_airtempmin = pd.read_csv('airtempmin.csv', skiprows = 3)
show_airtempmin.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# In  [63]:
# Line 1:     show_airtempmin = pd.read_csv('airtempmin.csv', skiprows = 3)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\util\_decorators.py, in wrapper:
# Line 311:   return func(*args, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in read_csv:
# Line 586:   return _read(filepath_or_buffer, kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in _read:
# Line 482:   parser = TextFileReader(filepath_or_buffer, **kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in __init__:
# Line 811:   self._engine = self._make_engine(self.engine)
#
# ...

# %%
df_min = pd.read_csv(r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\weedlymmintemp.csv')
print (df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# In  [64]:
# Line 1:     df_min = pd.read_csv(r'C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\weedlymmintemp.csv')
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\util\_decorators.py, in wrapper:
# Line 311:   return func(*args, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in read_csv:
# Line 586:   return _read(filepath_or_buffer, kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in _read:
# Line 482:   parser = TextFileReader(filepath_or_buffer, **kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\io\parsers\readers.py, in __init__:
# ...

# %%
# get projection the same
arcpy.management.Project("weedlymmintemp", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\df", 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', None, 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', "NO_PRESERVE_SHAPE", None, "NO_VERTICAL")
arcpy.management.Project("weeklymmaxtemp", r"C:\Users\swimb\Documents\UMN\fall2022\GIS5571\Lab1\Googleplaces\Googleplaces.gdb\df_min", 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', None, 'PROJCS["NAD_1983_UTM_Zone_15N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-93.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', "NO_PRESERVE_SHAPE", None, "NO_VERTICAL")
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [65]:
# ...

# %%
# spatial join
arcpy.analysis.SpatialJoin("weedlymmintemp", "weeklymmaxtemp", "man_min_sj")
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [66]:
# Line 2:     arcpy.analysis.SpatialJoin("weedlymmintemp", "weeklymmaxtemp", "man_min_sj")
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\analysis.py, in SpatialJoin:
# Line 793:   raise e
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\analysis.py, in SpatialJoin:
# Line 790:   retval = convertArcObjectToPythonObject(gp.SpatialJoin_analysis(*gp_fixargs((target_features, join_features, out_feature_class, join_operation, join_type, field_mapping, match_option, search_radius, distance_field_name), True)))
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 512:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: Failed to execute. Parameters are not valid.
# ...
